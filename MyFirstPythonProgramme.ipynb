# %%
import pandas as pd

# %%
pd.read_excel(r"E:\Reports\Sales Summary-Dec'22..xlsx")
# Out:
#    Builder Wise    Unnamed: 1   Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           NaN           NaN          NaN         NaN         NaN
# 1     Team Name         (All)          NaN         NaN         NaN
# 2           NaN           NaN          NaN         NaN         NaN
# 3           NaN        Values          NaN         NaN         NaN
# 4       Builder  Sum of Count  Sum of Area         NaN         NaN
# ..          ...           ...          ...         ...         ...
# 56          NaN           NaN          NaN         NaN         NaN
# 57          NaN           NaN          NaN         NaN         NaN
# 58          NaN           NaN          NaN         NaN         NaN
# 59          NaN           NaN          NaN         NaN         NaN
# 60          NaN           NaN          NaN         NaN         NaN
#
#      Branch Wise Unnamed: 6  Unnamed: 7  Unnamed: 8         Team Wise  \
# 0            NaN        NaN         NaN         NaN               NaN
# ...
